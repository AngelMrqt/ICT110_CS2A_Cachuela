# %% [markdown]
# Exercise 1

# %%
Print('Hello world!')
# the p in print is capital letter.

# %%
print('Hello world!')

# %%
print'Hello world!')
# a parenthesis is missing.

# %%
print('Hello world!')

# %%
print('Hello world!)
# a closing qoutation mark is missing.

# %%
print('Hello world!')

# %%
print('Hello world!'')
# there is an extra closing qoutation mark.

# %%
print('Hello world!')

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)

# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = X + 1
print(x)

# the X has no value.

# %%
x = 43
x = x + 1
print(x)

# %%
# !git config --global user.name =  'AngelMrqt'
# !git config --global user.email = 'angelmariquet.cachuela@students.isatu.edu.ph'
# !git config --global user.password = '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'

# %%
# !git clone https://AngelMrqt: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@github.com/AngelMrqt/ICT110_CS2A_Cachuela.git
# Out:
# Cloning into 'ICT110_CS2A_Cachuela'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 24.63 KiB | 6.16 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %ls
# Out:
# ICT110_CS2A_Cachuela/  sample_data/

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter1_Exercises.ipynb" "/content/ICT110_CS2A_Cachuela"

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/ICT110_CS2A_Cachuela
# Out:
# /content/ICT110_CS2A_Cachuela

# %%
# !pwd
# Out:
# /content/ICT110_CS2A_Cachuela

# %%
# %ls
# Out:
# Chapter1_Exercises.ipynb  Python_Workbook1.ipynb  Sample_text.txt

# %%
# %ls
# Out:
# Reinitialized existing Git repository in /content/ICT110_CS2A_Cachuela/.git/

# %%
# !git add Workbook_1/Chapter1_Exercises.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git commit -m 'additional commit'
# Out:
# On branch main
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.65 KiB | 1.65 MiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# remote: error: GH013: Repository rule violations found for refs/heads/main.
# remote: Review all repository rules at http://github.com/AngelMrqt/ICT110_CS2A_Cachuela/rules?ref=refs%2Fheads%2Fmain
# remote:
# remote: - GITHUB PUSH PROTECTION
# remote:   ——————————————————————————————————————————————————————
# remote:    Resolve the following secrets before pushing again.
# remote:
# remote:    (?) Learn how to resolve a blocked push
# remote:    https://docs.github.com/code-security/secret-scanning/pushing-a-branch-blocked-by-push-protection
# remote:
# remote:
# remote:   —— GitHub Personal Access Token ——————————————————————
# remote:    locations:
# ...
